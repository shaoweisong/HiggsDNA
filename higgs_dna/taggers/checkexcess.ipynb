# %%
import awkward as ak
import matplotlib.pyplot as plt

# %%
event=ak.from_parquet("/eos/user/z/zhenxuan/hhwwgg_workspace/hhwwgg_root/hhwwgg_root_PNNFH_HH/MX3000_MH125/data_2017_PNNscore.parquet")

# %%
eventdnn=event[event.PNN_score>0.03]
eventdnn_sig=eventdnn[(eventdnn.Diphoton_mass<135)&(eventdnn.Diphoton_mass>115)]

# %%
plt.hist(eventdnn.Diphoton_pt,range=(100,700),label="data diphotonpt")
plt.hist(eventdnn_sig.Diphoton_pt,range=(100,700),label="datasigregion diphotonpt",alpha=0.5)
plt.legend()

# %%
plt.hist(eventdnn.fatjet_1_Hqqqq_vsQCDTop,range=(0,1),label="data Hscore")
plt.hist(eventdnn_sig.fatjet_1_Hqqqq_vsQCDTop,range=(0,1),label="datasigregion Hscore",alpha=0.5)
plt.legend()

# %%
plt.hist(eventdnn.fatjet_1_Hqqqq_vsQCDTop,range=(0,1),label="data Hscore")
plt.hist(eventdnn_sig.fatjet_1_Hqqqq_vsQCDTop,range=(0,1),label="datasigregion Hscore",alpha=0.5)
plt.legend()

# %%
plt.hist(eventdnn.Diphoton_mass[eventdnn.fatjet_1_Hqqqq_vsQCDTop>0],range=(100,180),label="data diphotonmass",alpha=0.5,bins=15)
plt.hist(eventdnn.Diphoton_mass[eventdnn.fatjet_1_Hqqqq_vsQCDTop>0.4],range=(100,180),alpha=0.2,label="data diphotonmass(H>0.4)",bins=15)
plt.hist(eventdnn.Diphoton_mass[(eventdnn.fatjet_1_Hqqqq_vsQCDTop>0.4)&(eventdnn.Diphoton_pt>250)],range=(100,180),label="data diphotonmass(H>0.4,diphotonpt>250)",bins=15)

plt.legend()

# %%
signal=ak.from_parquet("/eos/cms/store/group/phys_b2g/shsong/HiggsDNAoutput/HH_FHsignal_highmass17/GluGluToRadionToHHTo2G2WTo2G4Q_M-3000_2017/merged_nominal.parquet")
plt.hist(signal.Diphoton_pt,bin=100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 2
#       1 signal=ak.from_parquet("/eos/cms/store/group/phys_b2g/shsong/HiggsDNAoutput/HH_FHsignal_highmass17/GluGluToRadionToHHTo2G2WTo2G4Q_M-3000_2017/merged_nominal.parquet")
# ----> 2 plt.hist(signal.Diphoton_pt,bin=100)
#
# File /eos/user/s/shsong/Miniconda/envs/higgsdna/lib/python3.9/site-packages/matplotlib/pyplot.py:3224, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3199 @_copy_docstring_and_deprecators(Axes.hist)
#    3200 def hist(
#    3201     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3222     BarContainer | Polygon | list[BarContainer | Polygon],
#    3223 ]:
# -> 3224     return gca().hist(
#    3225         x,
#    3226         bins=bins,
#    3227         range=range,
# ...
